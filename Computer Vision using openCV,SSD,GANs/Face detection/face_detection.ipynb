# %%
import cv2

# %%
face_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/Udemy learning path/A-Z AI- openCV, SSD, GANs/mod1- face detection/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/Udemy learning path/A-Z AI- openCV, SSD, GANs/mod1- face detection/haarcascade_eye.xml')

# %%
def detect(gray, frame):
  faces = face_cascade.detectMultiScale(gray, 1.3, 5)
  for (x,y,w,h) in faces:
    cv2.rectangle(faces,(x,y), (x+w, y+h), (225,0,0), 2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = frame[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray, 1.1, 3)
    for (ex,ey,ew,eh) in eyes:
      cv2.rectangle(roi_color, (ex,ey), (ex+ew, ey+eh), (0,225,0), 2)
  return frame

# %%
video_capture = take_photo()
while True:
  _, frame = video_capture.read()
  gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
  canvas = detect(gray, frame)
  cv2.imshow('Video', canvas)
  if cv2.waitKay(1) & 0xFF==ord('q'):
    break

video_capture.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-15-7757b7031dd0> in <module>()
#       2 while True:
#       3   _, frame = video_capture.read()
# ----> 4   gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       5   canvas = detect(gray, frame)
#       6   cv2.imshow('Video', canvas)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
